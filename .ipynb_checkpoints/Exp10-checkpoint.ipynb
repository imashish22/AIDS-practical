# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('realestate4.csv')
df.head()
# Out:
#    status  bed  bath  acre_lot  city  state  zip_code  house_size   price
# 0       0  1.0     1     20.20     1      0      1095        1751  299000
# 1       1  1.0     2      0.28     2      0      1030        1060  300000
# 2       0  4.0     2      0.16     3      0      1105        1402  199900
# 3       0  5.0     1      0.13     4      0      1040        1327  300000
# 4       0  3.0     1      0.13     5      0      1089        1715  299000

# %%
x = df.iloc[:,0:11] # 1st for rows and second for columns
x
# Out:
#       status  bed  bath  acre_lot  city  state  zip_code  house_size   price
# 0          0  1.0     1     20.20     1      0      1095        1751  299000
# 1          1  1.0     2      0.28     2      0      1030        1060  300000
# 2          0  4.0     2      0.16     3      0      1105        1402  199900
# 3          0  5.0     1      0.13     4      0      1040        1327  300000
# 4          0  3.0     1      0.13     5      0      1089        1715  299000
# ...      ...  ...   ...       ...   ...    ...       ...         ...     ...
# 7919       0  2.0     1      0.20   167      4      6118        1893  190000
# 7920       1  4.0     2      0.42   148      4      6082        1413  269900
# 7921       0  5.0     1      0.98   149      4      6071        1520  349900
# 7922       0  2.0     2      2.07   205      4      6438        1726  799000
# 7923       0  1.0     1      0.28   208      4      6450        1058  229900
#
# [7924 rows x 9 columns]

# %%
kmeans = KMeans(3) # Creating three clusters
kmeans.fit(x)
# Out:
# KMeans(n_clusters=3)

# %%
identified_clusters = kmeans.fit_predict(x)
identified_clusters
# Out:
# array([0, 0, 0, ..., 0, 2, 0])

# %%
data_with_clusters = df.copy()
data_with_clusters['Clusters'] = identified_clusters 
plt.scatter(data_with_clusters['status'],data_with_clusters['zip_code'],c=data_with_clusters['house_size'],cmap='rainbow')
